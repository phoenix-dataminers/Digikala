# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
cd /content/gdrive/My\ Drive/SetareToranj
# Out:
# /content/gdrive/My Drive/SetareToranj

# %%
df = pd.read_excel('digi_clean_final.xlsx')

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
from textblob import TextBlob

# %%
#get text length and word count
df['comment_len'] = df['comment'].astype(str).apply(len)
df['word_count'] = df['comment'].apply(lambda x: len(str(x).split()))

# %%
df.head()
# Out:
#                                        product_title  ... catg_dislikes
# 0  شارژر همراه شیاومی مدل NDY-02-AN با ظرفیت 1000...  ...           -75
# 1              یدک پولیشر میکروفایبر مهسان مدل 20119  ...           -75
# 2   گوشی موبایل هوآوی آنر مدل 5X KIW-L21 دو سیم‌کارت  ...           -75
# 3  شارژر همراه شیائومی مدل Mi ظرفیت 5000 میلی آمپ...  ...           -75
# 4               لپ تاپ 15 اینچی ایسوس مدل N501VW - A  ...           -75
#
# [5 rows x 13 columns]

# %%
#number of comment with no likes and dislikes
df[(df['likes'] == 0) & (df['dislikes'] == 0)].count()
# Out:
# product_title    0
# title_en         0
# likes            0
# dislikes         0
# recommend        0
# title            0
# comment          0
# advantages       0
# disadvantages    0
# comment_len      0
# word_count       0
# catg_likes       0
# catg_dislikes    0
# dtype: int64

# %%
df_nz = df.drop(df[(df['likes'] == 0) & (df['dislikes'] == 0)].index)

# %%
df_nz.head(40)
# Out:
#                                         product_title  ... catg_dislikes
# 0   شارژر همراه شیاومی مدل NDY-02-AN با ظرفیت 1000...  ...           -75
# 1               یدک پولیشر میکروفایبر مهسان مدل 20119  ...           -75
# 2    گوشی موبایل هوآوی آنر مدل 5X KIW-L21 دو سیم‌کارت  ...           -75
# 3   شارژر همراه شیائومی مدل Mi ظرفیت 5000 میلی آمپ...  ...           -75
# 4                لپ تاپ 15 اینچی ایسوس مدل N501VW - A  ...           -75
# 5              اسپیکر بلوتوثی دیووم مدل Bluetune bean  ...           -75
# 6   ادو پرفیوم زنانه امپر مدل Chifon حجم 100 میلی ...  ...           -75
# 7                ماشین اصلاح صورت رمینگتون مدل MB4555  ...           -75
# 8      فلاسک هنری مدل Virginia Special ظرفیت 1.9 لیتر  ...           -75
# 9   هارددیسک اکسترنال سیگیت مدل Backup Plus Deskto...  ...           -75
# 10                     شمع خودرو ان جی کی مدل BKR6EGP  ...           -75
# 11                    ماشین بازی بیبی لند مدل Top Car  ...           -75
# 12     شارژر همراه لنوو با ظرفیت 10400 میلی آمپر ساعت  ...           -75
# 13        خودتراش سیلور مدل M5 Magnum به همراه یک یدک  ...           -75
# 14            فلاسک غذا خودرو بلک اند دکر مدل BDV212F  ...           -75
# 15  کرم نرم کننده دست و صورت آلوئه ورا کاسه ای مای...  ...           -75
# 16                                 ماساژور بیورر MG80  ...           -75
# 17                 مچ‌ بند هوشمند آی واون مدل i5 Plus  ...           -75
# 18  ماشین اصلاح صورت پاناسونیک سری Lamdash مدل ES-...  ...           -75
# 19                             هدفون کریتیو مدل MA200  ...           -75
# 20  هارددیسک اکسترنال ترنسند مدل StoreJet 25H3 ظرف...  ...           -75
# 21  ادو تویلت مردانه دیور مدل Sauvage حجم 100 میلی...  ...           -75
# 22  روغن موتور خودرو توتال مدل Quartz 7000 حجم 4 لیتر  ...           -75
# 23                            اسپیکر هترون مدل HSP260  ...           -75
# 24  گوشی موبایل ال‌جی مدل G4 H818P دو سیم‌کارت ظرف...  ...           -75
# 25  گوشی موبایل هوآوی مدل Mate 8 دو سیم‌کارت - ظرف...  ...           -75
# 26  گوشی موبایل تی پی-لینک مدل Neffos C5 Max TP702...  ...           -75
# 27     اسپری مردانه اکس  مدل Apollo حجم 150 میلی لیتر  ...           -75
# 28                    جعبه نظم دهنده صندوق خودرو تاشو  ...           -75
# 29        گوشی موبایل ال جی مدل V10 ظرفیت 32 گیگابایت  ...           -75
# 30                          هدفون شیائومی مدل Quantie  ...           -75
# 31              هدست واقعیت مجازی سامسونگ مدل Gear VR  ...           -75
# 32     پایه نگهدارنده گوشی موبایل دبلیو کی مدل WA-S01  ...           -75
# 33           نرم افزار آموزشی زبان ساتل انگلیسی شیرین  ...           -75
# 34  شارژر همراه روموس مدل Polymos 20 ظرفیت 20000 م...  ...           -75
# 35  گوشی موبایل هوآوی مدل P8 دو سیم کارت - 64 گیگا...  ...           -75
# 36                            جاروبرقی فلر مدل VC 206  ...           -75
# 37  شارژر همراه هوآوی مدل AP007 ظرفیت 13000 میلی آ...  ...           -75
# 38                    هدفون بی سیم ای کی جی مدل Y50BT  ...           -75
# 39  ادو تویلت زنانه خسوس دل پوزو مدل Halloween حجم...  ...           -75
#
# [40 rows x 13 columns]

# %%
df_nz.describe()
# Out:
#               likes      dislikes     recommend   comment_len    word_count
# count  73469.000000  73469.000000  73469.000000  73469.000000  73469.000000
# mean       4.239598      2.245110      1.203419    125.309477     24.206958
# std        9.134335     10.333697      0.696272    155.785497     29.872676
# min        0.000000      0.000000      0.000000      1.000000      0.000000
# 25%        1.000000      0.000000      1.000000     40.000000      8.000000
# 50%        2.000000      1.000000      1.000000     81.000000     16.000000
# 75%        5.000000      2.000000      2.000000    154.000000     30.000000
# max      854.000000   1344.000000      2.000000   4889.000000    949.000000

# %%
df_nz[df_nz['likes'] >=2].count()
# Out:
# product_title    46981
# title_en         46981
# likes            46981
# dislikes         46981
# recommend        46981
# title            46981
# comment          46981
# advantages       46981
# disadvantages    46981
# comment_len      46981
# word_count       46981
# catg_likes       46981
# catg_dislikes    46981
# dtype: int64

# %%
df_nz[df_nz['dislikes'] >=1].count()
# Out:
# product_title    42562
# title_en         42562
# likes            42562
# dislikes         42562
# recommend        42562
# title            42562
# comment          42562
# advantages       42562
# disadvantages    42562
# comment_len      42562
# word_count       42562
# catg_likes       42562
# catg_dislikes    42562
# dtype: int64

# %%
df_nz.word_count.describe()
# Out:
# count    73469.000000
# mean        24.206958
# std         29.872676
# min          0.000000
# 25%          8.000000
# 50%         16.000000
# 75%         30.000000
# max        949.000000
# Name: word_count, dtype: float64

# %%
df_nz.comment_len.describe()
# Out:
# count    73469.000000
# mean       125.309477
# std        155.785497
# min          1.000000
# 25%         40.000000
# 50%         81.000000
# 75%        154.000000
# max       4889.000000
# Name: comment_len, dtype: float64

# %%
# Density Plot and Histogram of product title_en
df_nz.title_en.hist()

# %%
# Density Plot and Histogram of comment word count
sns.distplot(df_nz['word_count'], hist=True, kde=True, 
             bins=int(180/5), color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 2})

# %%
# GROUP UNIQUE COMMENTS BASED ON RECOMMEND STATUS
#recommend plot - 0: not recommend, 1: no idea , 2: recommend
df_nz.groupby('recommend')['comment'].nunique().plot(kind='bar')
plt.show()
######################################################################
# RESULT
#There are 15000 unique comments for products which are not recommended  
#There are about 50000 unique comments for products which are no idea
#There are 35000 unique comments for products which are recommended

# %%
# GROUP UNIQUE LIKES BASED ON RECOMMEND STATUS
# 0: not recommend, 1: no idea , 2: recommend
df_nz.groupby('recommend')['likes'].nunique().plot(kind='bar')
plt.show()
######################################################################
# RESULT
#There are about 85 unique likes for products which are not recommended  
#There are 140 unique likes for products which are no idea
#There are about 70 unique likes for products which are not recommended

# %%
# GROUP UNIQUE DISLIKES BASED ON RECOMMEND STATUS
# 0: not recommend, 1: no idea , 2: recommend
df_nz.groupby('recommend')['dislikes'].nunique().plot(kind='bar')
plt.show()
######################################################################
# RESULT
#There are 50 unique dislikes for products which are not recommended  
#There are about 130 unique dislikes for products which are no idea
#There are 60 unique dislikes for products which are not recommended

# %%
# GROUP COMMENTS BASED ON PRODUCT TITLE AND RECOMMEND STATUS
# 0: not recommend, 1: no idea , 2: recommend
df_nz.groupby(['title_en','recommend']).size().unstack().plot(kind='bar',stacked=True)
plt.show()
######################################################################
# RESULT
#There are 2500 comments about AC Products which is not recommended, 4500 is no idea and 5500 is recommended
#There are 1000 comments about PC Products which is not recommended, 5500 is no idea and 3500 is recommended

# %%
import matplotlib.ticker as mtick
# GROUP COMMENTS BASED ON PRODUCT TITLE AND RECOMMEND STATUS IN PERCENTAGE
# 0: not recommend, 1: no idea , 2: recommend
df_nz.groupby(['title_en','recommend']).size().groupby(level=0).apply(
    lambda x: 100 * x / x.sum()
).unstack().plot(kind='bar',stacked=True)

plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter())
plt.show()
######################################################################
# RESULT
#22% of comments about AC Products is not recommended, 40% is no idea and 40% is recommended
#5% of comments about FF Products is not recommended, 60% is no idea and3 35% is recommended

# %%
#Categorical likes and dislikes
def cat(x):
    if x <= 75:
        return "-75"
    if x > 150:
        return "+150"
    return "between"

# %%
df_nz['catg_likes'] = df_nz['likes'].apply(lambda x: cat(x))
df_nz['catg_dislikes'] = df_nz['dislikes'].apply(lambda x: cat(x))

# %%
lowlike = df_nz.likes[df_nz.likes <= 75].count()
highlike = df_nz.likes[df_nz.likes > 150].count()
midlike = df_nz.likes[(df_nz['likes'] > 75) & (df_nz['likes'] <= 150)].count()

# %%
print('number of comments under 75 likes: {} - number of comments more than 150 likes: {} - number of comments between 75 and 150 likes: {} ' .format(lowlike, highlike, midlike))
# Out:
# number of comments under 75 likes: 73343 - number of comments more than 150 likes: 24 - number of comments between 75 and 150 likes: 102

# %%
lowdislike = df_nz.dislikes[df_nz.dislikes <= 75].count()
highdislike = df_nz.dislikes[df_nz.dislikes > 150].count()
middislike = df_nz.dislikes[(df_nz['dislikes'] > 75) & (df_nz['dislikes'] <= 150)].count()

# %%
print('number of comments under 75 dislikes: {} - number of comments more than 150 dislikes: {} - number of comments between 75 and 150 dislikes: {} ' .format(lowdislike, highdislike, middislike))
# Out:
# number of comments under 75 dislikes: 73379 - number of comments more than 150 dislikes: 31 - number of comments between 75 and 150 dislikes: 59

# %%
# GROUP UNIQUE COMMENTS BASED ON NUMBER OF Likes
df_nz.groupby('catg_likes')['comment'].nunique().plot(kind='bar')
plt.show()

# %%
# GROUP UNIQUE COMMENTS BASED ON NUMBER OF DisLikes
df_nz.groupby('catg_dislikes')['comment'].nunique().plot(kind='bar')
plt.show()

# %%
# GROUP COMMENTS BASED ON PRODUCT TITLE AND LIKES STATUS
df_nz.groupby(['title_en','catg_likes']).size().unstack().plot(kind='bar',stacked=True)
plt.show()
######################################################################
# RESULT
#There is 12000 comments about AC Products with less than 75 likes 
# All the products mostly have likes less than 75 
# FF, GC and BC product titles have lowest likes (nearly with no likes)

# %%
df_nz.groupby(['recommend','catg_likes']).size().unstack().plot(kind='bar',stacked=True)
plt.show()
######################################################################
# RESULT
#no ides comment has most less likes

# %%
# GROUP COMMENTS BASED ON PRODUCT TITLE AND LIKES STATUS
df_nz.groupby(['title_en','catg_dislikes']).size().unstack().plot(kind='bar',stacked=True)
plt.show()
######################################################################
#There is 12000 comments about AC Products with less than 75 dislikes 
# All the products mostly have dislikes less than 75 
# FF, GC and BC product titles have lowest dislikes (nearly with no dislikes)

# %%
df_nz.groupby(['recommend','catg_dislikes']).size().unstack().plot(kind='bar',stacked=True)
plt.show()
######################################################################
# RESULT
#Most of the dislikes are less than 75

# %%
df_nz.groupby(['catg_dislikes','recommend']).size().unstack().plot(kind='bar',stacked=True)
plt.show()
######################################################################
# RESULT
#Most of the dislikes less than 75 are about no idea comment

# %%
#Get Most Frequent Words
from collections import Counter
freq = Counter(" ".join(df_nz["comment"]).split()).most_common(60)

# %%
n = 0 # N. . .
word_text = [x[n] for x in freq]

# %%
#Plot thr common words
data = freq

n_groups = len(data)

vals_films = [x[1] for x in data]
legends_films = [x[0] for x in data]

fig, ax = plt.subplots()

index = np.arange(n_groups)
bar_width = 0.25

opacity = 0.4

rects1 = plt.bar(index, vals_films, bar_width,
                 alpha=opacity,
                 color='b',
                 label='Ocurrences')


plt.xlabel('Words')
plt.ylabel('Frequency')
plt.title('Top 10 words in comment')
plt.xticks(index + bar_width, legends_films,rotation=90)
plt.legend()

plt.tight_layout()
plt.show()

# %%
from wordcloud import WordCloud
from wordcloud import STOPWORDS
from textblob import TextBlob
from textblob import Word

# %%
# Group Comments based on likes
df3 = df_nz.groupby('catg_likes').agg(lambda x: x.tolist())

# %%
# Group Comments based on dislikes
df4 = df_nz.groupby('catg_dislikes').agg(lambda x: x.tolist())

# %%
df_lowlike = df_nz[df_nz['catg_likes'] == '-75']

# %%
df_midlike = df_nz[df_nz['catg_likes'] == 'between']

# %%
df_highlike = df_nz[df_nz['catg_likes'] == '+150']

# %%
df_lowdislike = df_nz[df_nz['catg_dislikes'] == '-75']

# %%
df_middislike = df_nz[df_nz['catg_dislikes'] == '-75']

# %%
df_highdislike = df_nz[df_nz['catg_dislikes'] == '-75']

# %%
#Get Most Frequent Words in comment in low likes
freq = Counter(" ".join(df_lowlike["comment"]).split()).most_common(10)

# %%
freq
# Out:
# [('خیلی', 30054),
#  ('رو', 28180),
#  ('داره', 18700),
#  ('ولی', 16224),
#  ('استفاده', 14156),
#  ('هست', 13938),
#  ('کیفیت', 13236),
#  ('میشه', 10999),
#  ('خریدم', 10934),
#  ('های', 10440)]

# %%
#Plot the common words
data = freq

n_groups = len(data)

vals_films = [x[1] for x in data]
legends_films = [x[0] for x in data]

fig, ax = plt.subplots()

index = np.arange(n_groups)
bar_width = 0.25

opacity = 0.4

rects1 = plt.bar(index, vals_films, bar_width,
                 alpha=opacity,
                 color='b',
                 label='Ocurrences')


plt.xlabel('Words')
plt.ylabel('Frequency')
plt.title('Top 10 words in comment for low likes')
plt.xticks(index + bar_width, legends_films, rotation=90)
plt.legend()

plt.tight_layout()
plt.show()

# %%
#Get Most Frequent Words in comment in mid likes
freq2 = Counter(" ".join(df_midlike["comment"]).split()).most_common(10)
freq2
# Out:
# [('رو', 85),
#  ('خیلی', 64),
#  ('هست', 43),
#  ('ولی', 40),
#  ('های', 40),
#  ('استفاده', 35),
#  ('گوشی', 33),
#  ('داره', 33),
#  ('شارژ', 32),
#  ('میشه', 31)]

# %%
#Plot the common words
data = freq2

n_groups = len(data)

vals_films = [x[1] for x in data]
legends_films = [x[0] for x in data]

fig, ax = plt.subplots()

index = np.arange(n_groups)
bar_width = 0.25

opacity = 0.4

rects1 = plt.bar(index, vals_films, bar_width,
                 alpha=opacity,
                 color='b',
                 label='Ocurrences')


plt.xlabel('Words')
plt.ylabel('Frequency')
plt.title('Top 10 words in comment for mid likes')
plt.xticks(index + bar_width, legends_films, rotation=90)
plt.legend()

plt.tight_layout()
plt.show()

# %%
#Get Most Frequent Words in comment in high likes
freq3 = Counter(" ".join(df_highlike["comment"]).split()).most_common(10)
freq3
# Out:
# [('رو', 54),
#  ('کنید', 26),
#  ('یه', 16),
#  ('هست', 16),
#  ('ایرباد', 15),
#  ('داره', 14),
#  ('میشه', 14),
#  ('ها', 13),
#  ('اگه', 12),
#  ('گوشی', 11)]

# %%
#Plot the common words
data = freq3

n_groups = len(data)

vals_films = [x[1] for x in data]
legends_films = [x[0] for x in data]

fig, ax = plt.subplots()

index = np.arange(n_groups)
bar_width = 0.25

opacity = 0.4

rects1 = plt.bar(index, vals_films, bar_width,
                 alpha=opacity,
                 color='b',
                 label='Ocurrences')


plt.xlabel('Words')
plt.ylabel('Frequency')
plt.title('Top 10 words in comment for high likes')
plt.xticks(index + bar_width, legends_films, rotation=90)
plt.legend()

plt.tight_layout()
plt.show()

# %%
#Get Most Frequent Words in comment in low dislikes
freq4 = Counter(" ".join(df_lowdislike["comment"]).split()).most_common(10)
freq4
# Out:
# [('خیلی', 30089),
#  ('رو', 28276),
#  ('داره', 18728),
#  ('ولی', 16253),
#  ('استفاده', 14184),
#  ('هست', 13983),
#  ('کیفیت', 13250),
#  ('میشه', 11035),
#  ('خریدم', 10932),
#  ('های', 10467)]

# %%
#Plot the common words
data = freq4

n_groups = len(data)

vals_films = [x[1] for x in data]
legends_films = [x[0] for x in data]

fig, ax = plt.subplots()

index = np.arange(n_groups)
bar_width = 0.25

opacity = 0.4

rects1 = plt.bar(index, vals_films, bar_width,
                 alpha=opacity, 
                 color='b',
                 label='Ocurrences')


plt.xlabel('Words')
plt.ylabel('Frequency')
plt.title('Top 10 words in comment for low dislikes')
plt.xticks(index + bar_width, legends_films, rotation=90)
plt.legend()

plt.tight_layout()
plt.show()

# %%
#Get Most Frequent Words in comment in mid dislikes
freq5 = Counter(" ".join(df_middislike["comment"]).split()).most_common(10)
freq5
# Out:
# [('خیلی', 30089),
#  ('رو', 28276),
#  ('داره', 18728),
#  ('ولی', 16253),
#  ('استفاده', 14184),
#  ('هست', 13983),
#  ('کیفیت', 13250),
#  ('میشه', 11035),
#  ('خریدم', 10932),
#  ('های', 10467)]

# %%
#Plot the common words
data = freq5

n_groups = len(data)

vals_films = [x[1] for x in data]
legends_films = [x[0] for x in data]

fig, ax = plt.subplots()

index = np.arange(n_groups)
bar_width = 0.25

opacity = 0.4

rects1 = plt.bar(index, vals_films, bar_width,
                 alpha=opacity,
                 color='b',
                 label='Ocurrences')


plt.xlabel('Words')
plt.ylabel('Frequency')
plt.title('Top 10 words in comment for mid dislikes')
plt.xticks(index + bar_width, legends_films, rotation=90)
plt.legend()

plt.tight_layout()
plt.show()

# %%
#Get Most Frequent Words in comment in high dislikes
freq6 = Counter(" ".join(df_highdislike["comment"]).split()).most_common(10)
freq6
# Out:
# [('خیلی', 30089),
#  ('رو', 28276),
#  ('داره', 18728),
#  ('ولی', 16253),
#  ('استفاده', 14184),
#  ('هست', 13983),
#  ('کیفیت', 13250),
#  ('میشه', 11035),
#  ('خریدم', 10932),
#  ('های', 10467)]

# %%
n = 0 # N. . .
[x[n] for x in freq6]
# Out:
# ['خیلی',
#  'رو',
#  'داره',
#  'ولی',
#  'استفاده',
#  'هست',
#  'کیفیت',
#  'میشه',
#  'خریدم',
#  'های']

# %%
#Plot the common words
data = freq6

n_groups = len(data)

vals_films = [x[1] for x in data]
legends_films = [x[0] for x in data]

fig, ax = plt.subplots()

index = np.arange(n_groups)
bar_width = 0.25

opacity = 0.4

rects1 = plt.bar(index, vals_films, bar_width,
                 alpha=opacity,
                 color='b',
                 label='Ocurrences')


plt.xlabel('Words')
plt.ylabel('Frequency')
plt.title('Top 10 words in comment for high dislikes')
plt.xticks(index + bar_width, legends_films, rotation=90)
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Word Cloud

# %%
# !pip install persian_wordcloud
# Out:
# Collecting persian_wordcloud
#   Downloading https://files.pythonhosted.org/packages/d5/3f/403b901f6b40902db4b851a3591ebbd7189579c63a4c159926b76a0d8869/persian_wordcloud-1.3.1.tar.gz (65kB)
#      |████████████████████████████████| 71kB 4.5MB/s
# Collecting arabic_reshaper
#   Downloading https://files.pythonhosted.org/packages/1c/b8/9f87dc2fc6c2e087e448db9e7f66ca4d68c22e9d49a95e5aad22d77c74f1/arabic_reshaper-2.0.15-py3-none-any.whl
# Collecting python-bidi
#   Downloading https://files.pythonhosted.org/packages/33/b0/f942d146a2f457233baaafd6bdf624eba8e0f665045b4abd69d1b62d097d/python_bidi-0.4.2-py2.py3-none-any.whl
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.6/dist-packages (from persian_wordcloud) (1.5.0)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from arabic_reshaper->persian_wordcloud) (0.16.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from arabic_reshaper->persian_wordcloud) (45.2.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from python-bidi->persian_wordcloud) (1.12.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from wordcloud->persian_wordcloud) (6.2.2)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.6/dist-packages (from wordcloud->persian_wordcloud) (1.17.5)
# Building wheels for collected packages: persian-wordcloud
#   Building wheel for persian-wordcloud (setup.py) ... done
#   Created wheel for persian-wordcloud: filename=persian_wordcloud-1.3.1-cp36-none-any.whl size=65942 sha256=26c586c5804551716f98d83c5039211e4d4d1924cad0f520ec02dc3940132736
#   Stored in directory: /root/.cache/pip/wheels/d6/cb/3e/9cbd2b569d53b1442208fa3a4c66c2fc2bd6ade54231d08549
# Successfully built persian-wordcloud
# Installing collected packages: arabic-reshaper, python-bidi, persian-wordcloud
# Successfully installed arabic-reshaper-2.0.15 persian-wordcloud-1.3.1 python-bidi-0.4.2

# %%
from os import path
from persian_wordcloud.wordcloud import PersianWordCloud, add_stop_words
import matplotlib.image as mpimg

# %%
stopwords = []
file = open('stopwords-fa2.txt').read()
[stopwords.append(x) for x in file.split('\n')]
stopwords = set(stopwords)

# %% [markdown]
# ###Show Most Frequent Words in Comments

# %%
with open("freq_words.txt", "w") as output:
    output.write(str(word_text))

# %%
text = open('freq_words.txt', encoding='utf-8').read()

# %%
wordcloud = PersianWordCloud(only_persian=True,
max_words=100,
stopwords=stopwords,
margin=0,
width=800,
height=800,
    min_font_size=1,
    max_font_size=500,
    background_color="black"
).generate(text)

# %%
image = wordcloud.to_image()
image.show()

# %%
image.save('wordcloud.png')

# %%
import matplotlib.image as mpimg
img=mpimg.imread('wordcloud.png')
plt.figure(figsize = (10,10))
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# ### Show Most Frequent Words as DISADVANTAGES in Highly Disliked Comments

# %%
#Get Most Frequent Words
from collections import Counter
freq7 = Counter(" ".join(df_highdislike["disadvantages"]).split()).most_common(30)

# %%
n = 0 # N. . .
negative_text = [x[n] for x in freq7]

# %%
with open("negative_words.txt", "w") as output:
    output.write(str(negative_text))

# %%
text = open('negative_words.txt', encoding='utf-8').read()
wordcloud = PersianWordCloud(only_persian=True,
max_words=100,
stopwords=stopwords,
margin=0,
width=800,
height=800,
    min_font_size=1,
    max_font_size=500,
    background_color="black"
).generate(text)

image = wordcloud.to_image()
image.show()

image.save('negative_wordcloud.png')

# %%
img=mpimg.imread('negative_wordcloud.png')
plt.figure(figsize = (10,10))
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# ##### Show Most Frequent Words as ADVANTAGES in Highly liked Comments

# %%
#Get Most Frequent Words
from collections import Counter
freq8 = Counter(" ".join(df_highlike["advantages"]).split()).most_common(30)

# %%
n = 0 # N. . .
positive_text = [x[n] for x in freq8]

# %%
with open("positive_words.txt", "w") as output:
    output.write(str(positive_text))

# %%
text = open('positive_words.txt', encoding='utf-8').read()
wordcloud = PersianWordCloud(only_persian=True,
max_words=100,
stopwords=stopwords,
margin=0,
width=800,
height=800,
    min_font_size=1,
    max_font_size=500,
    background_color="black"
).generate(text)

image = wordcloud.to_image()
image.show()

image.save('positive_wordcloud.png')

# %%
img=mpimg.imread('positive_wordcloud.png')
plt.figure(figsize = (10,10))
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# ### Word Cloud For AC Product with High Likes and Low Dislikes

# %%
df_positive_AC = df_nz[(df_nz['title_en'] == 'AC') & (df_nz['catg_likes'] == '+150') & (df_nz['catg_dislikes'] == '-75')]

# %%
df_positive_AC = df_nz[(df_nz['title_en'] == 'AC') & (df_nz['catg_likes'] == '+150') & (df_nz['catg_dislikes'] == '-75')]
# Handsfree Bluetooth
df_positive_AC.head(40)
# Out:
#                     product_title title_en  ...  catg_likes  catg_dislikes
# 24764  هندزفری بلوتوث مدل i7S-TWS       AC  ...        +150            -75
#
# [1 rows x 13 columns]

# %%
#Get Most Frequent Words 
from collections import Counter
ac_comm = Counter(" ".join(df_positive_AC["comment"]).split()).most_common(30)


n = 0 # N. . .
positive_ac1 = [x[n] for x in ac_comm]


with open("positive_ac1.txt", "w") as output:
    output.write(str(positive_ac1))



text = open('positive_ac1.txt', encoding='utf-8').read()
wordcloud = PersianWordCloud(only_persian=True,
max_words=100,
stopwords=stopwords,
margin=0,
width=800,
height=800,
    min_font_size=1,
    max_font_size=500,
    background_color="black"
).generate(text)

image = wordcloud.to_image()
image.show()

image.save('positive_ac1_wc.png')



img=mpimg.imread('positive_ac1_wc.png')
plt.figure(figsize = (10,10))
imgplot = plt.imshow(img)
plt.show()

# %%
n = 0 # N. . .
positive_ac1 = [x[n] for x in ac_comm]

# %%
with open("positive_ac1.txt", "w") as output:
    output.write(str(positive_ac1))

# %%
text = open('positive_ac1.txt', encoding='utf-8').read()
wordcloud = PersianWordCloud(only_persian=True,
max_words=100,
stopwords=stopwords,
margin=0,
width=800,
height=800,
    min_font_size=1,
    max_font_size=500,
    background_color="black"
).generate(text)

image = wordcloud.to_image()
image.show()

image.save('positive_ac1_wc.png')

# %%
img=mpimg.imread('positive_ac1_wc.png')
plt.figure(figsize = (10,10))
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# ### Word Cloud For AC Product with LOw LIkes and Hight/Medium Dislikes

# %%
df_negative_AC = df_nz[(df_nz['title_en'] == 'AC') & (df_nz['catg_likes'] == '-75') & (df_nz['catg_dislikes'] == 'between')]

# %%
df_negative_AC.head()
# Out:
#                                            product_title  ... catg_dislikes
# 14851                اینورتر فنجانی انرجایزر مدل 180WATT  ...       between
# 19455  شارژر همراه انکر مدل A1214 PowerCore ظرفیت 104...  ...       between
# 60737  شارژر دیواری مک کوی مدل MC-CH01 به همراه 2 عدد...  ...       between
#
# [3 rows x 13 columns]

# %%
#Get Most Frequent Words for AC products in comments
from collections import Counter
ac_comm2 = Counter(" ".join(df_negative_AC["comment"]).split()).most_common(30)

n = 0 # N. . .
negative_ac1 = [x[n] for x in ac_comm2]

with open("negative_ac1.txt", "w") as output:
    output.write(str(negative_ac1))

text = open('negative_ac1.txt', encoding='utf-8').read()
wordcloud = PersianWordCloud(only_persian=True,
max_words=100,
stopwords=stopwords,
margin=0,
width=800,
height=800,
    min_font_size=1,
    max_font_size=500,
    background_color="black"
).generate(text)

image = wordcloud.to_image()
image.show()

image.save('negative_ac1_wc.png')

img=mpimg.imread('negative_ac1_wc.png')
plt.figure(figsize = (10,10))
imgplot = plt.imshow(img)
plt.show()

# %%
df_nz.title_en.unique()
# Out:
# array(['AC', 'HW', 'MO', 'IT', 'PC', 'PA', 'TC', 'TS', 'MA', 'HA', 'AV',
#        'FA', 'HC', 'BC', 'DF', 'GC', 'FF'], dtype=object)

# %% [markdown]
# ### Word Cloud For HW Product with Mid Likes and Low Dislikes

# %%
df_pos_HW = df_nz[(df_nz['title_en'] == 'HW') & (df_nz['catg_likes'] == 'between') & (df_nz['catg_dislikes'] == '-75')]
df_pos_HW.head()
# Out:
#                              product_title title_en  ...  catg_likes  catg_dislikes
# 68103  لیوان گامین گلس مدل محک بسته 6 عددی       HW  ...     between            -75
#
# [1 rows x 13 columns]

# %%
#Get Most Frequent Words for HW products in comments
from collections import Counter
hw_comm1 = Counter(" ".join(df_pos_HW["comment"]).split()).most_common(30)

n = 0 # N. . .
pos_hw = [x[n] for x in hw_comm1]

with open("pos_hw.txt", "w") as output:
    output.write(str(pos_hw))

text = open('pos_hw.txt', encoding='utf-8').read()
wordcloud = PersianWordCloud(only_persian=True,
max_words=100,
stopwords=stopwords,
margin=0,
width=800,
height=800,
    min_font_size=1,
    max_font_size=500,
    background_color="black"
).generate(text)

image = wordcloud.to_image()
image.show()

image.save('pos_hw_wc.png')

img=mpimg.imread('pos_hw_wc.png')
plt.figure(figsize = (10,10))
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# ### Word Cloud For HW Product with Low Likes and Mid Dislikes

# %%
df_neg_HW = df_nz[(df_nz['title_en'] == 'HW') & (df_nz['catg_likes'] == '-75') & (df_nz['catg_dislikes'] == 'between')]
df_neg_HW.head()
# Out:
#                       product_title title_en  ...  catg_likes  catg_dislikes
# 26887           میز یوفیکس مدل لونا       HW  ...         -75        between
# 38909  فندک زیپو مدل Chinese Dragon       HW  ...         -75        between
# 50202           میز یوفیکس مدل لونا       HW  ...         -75        between
# 51200           میز یوفیکس مدل لونا       HW  ...         -75        between
#
# [4 rows x 13 columns]

# %%
#Get Most Frequent Words for HW products in comments
from collections import Counter
hw_comm2 = Counter(" ".join(df_pos_HW["comment"]).split()).most_common(30)

n = 0 # N. . .
neg_hw = [x[n] for x in hw_comm2]

with open("neg_hw.txt", "w") as output:
    output.write(str(neg_hw))

text = open('neg_hw.txt', encoding='utf-8').read()
wordcloud = PersianWordCloud(only_persian=True,
max_words=100,
stopwords=stopwords,
margin=0,
width=800,
height=800,
    min_font_size=1,
    max_font_size=500,
    background_color="black"
).generate(text)

image = wordcloud.to_image()
image.show()

image.save('neg_hw_wc.png')

img=mpimg.imread('neg_hw_wc.png')
plt.figure(figsize = (10,10))
imgplot = plt.imshow(img)
plt.show()

# %%
df_nz.to_excel("digi_clean2.xlsx")

# %%
df_nz.product_title.unique()[0:20]
# Out:
# array(['شارژر همراه شیاومی مدل NDY-02-AN با ظرفیت 10000 میلی آمپر ساعت',
#        'یدک پولیشر میکروفایبر مهسان مدل 20119',
#        'گوشی موبایل هوآوی آنر مدل 5X KIW-L21 دو سیم\u200cکارت',
#        'شارژر همراه شیائومی مدل Mi ظرفیت 5000 میلی آمپر ساعت',
#        'لپ تاپ 15 اینچی ایسوس مدل N501VW - A',
#        'اسپیکر بلوتوثی دیووم مدل Bluetune bean',
#        'ادو پرفیوم زنانه امپر مدل Chifon حجم 100 میلی لیتر',
#        'ماشین اصلاح صورت رمینگتون مدل MB4555',
#        'فلاسک هنری مدل Virginia Special ظرفیت 1.9 لیتر',
#        'هارددیسک اکسترنال سیگیت مدل Backup Plus Desktop ظرفیت 4 ترابایت',
#        'شمع خودرو ان جی کی مدل BKR6EGP',
#        'ماشین بازی بیبی لند مدل Top Car',
#        'شارژر همراه لنوو با ظرفیت 10400 میلی آمپر ساعت',
#        'خودتراش سیلور مدل M5 Magnum به همراه یک یدک',
#        'فلاسک غذا خودرو بلک اند دکر مدل BDV212F',
#        'کرم نرم کننده دست و صورت آلوئه ورا کاسه ای مای حجم 200 میلی لیتر',
#        'ماساژور بیورر MG80', 'مچ\u200c بند هوشمند آی واون مدل i5 Plus',
#        'ماشین اصلاح صورت پاناسونیک سری Lamdash مدل ES-GA20',
#        'هدفون کریتیو مدل MA200'], dtype=object)

# %%
test = df_nz[df_nz['product_title'] == 'شارژر همراه شیاومی مدل NDY-02-AN با ظرفیت 10000 میلی آمپر ساعت']
test.head()
# Out:
#                                            product_title  ... catg_dislikes
# 0      شارژر همراه شیاومی مدل NDY-02-AN با ظرفیت 1000...  ...           -75
# 183    شارژر همراه شیاومی مدل NDY-02-AN با ظرفیت 1000...  ...           -75
# 15351  شارژر همراه شیاومی مدل NDY-02-AN با ظرفیت 1000...  ...           -75
# 32401  شارژر همراه شیاومی مدل NDY-02-AN با ظرفیت 1000...  ...           -75
# 56605  شارژر همراه شیاومی مدل NDY-02-AN با ظرفیت 1000...  ...           -75
#
# [5 rows x 13 columns]

# %%
#Get Most Frequent Words for HW products in comments
from collections import Counter
test_comm2 = Counter(" ".join(test["comment"]).split()).most_common(30)

n = 0 # N. . .
test_list = [x[n] for x in test_comm2]

with open("test_list.txt", "w") as output:
    output.write(str(test_list))

text = open('test_list.txt', encoding='utf-8').read()
wordcloud = PersianWordCloud(only_persian=True,
max_words=100,
stopwords=stopwords,
margin=0,
width=800,
height=800,
    min_font_size=1,
    max_font_size=500,
    background_color="black"
).generate(text)

image = wordcloud.to_image()
image.show()

image.save('test_list_wc.png')

img=mpimg.imread('test_list_wc.png')
plt.figure(figsize = (10,10))
imgplot = plt.imshow(img)
plt.show()

# %%
#Get Most Frequent Words for HW products in comments
from collections import Counter
test_comm3 = Counter(" ".join(test["advantages"]).split()).most_common(30)

n = 0 # N. . .
test_list2 = [x[n] for x in test_comm3]

with open("test_list2.txt", "w") as output:
    output.write(str(test_list2))

text = open('test_list2.txt', encoding='utf-8').read()
wordcloud = PersianWordCloud(only_persian=True,
max_words=100,
stopwords=stopwords,
margin=0,
width=800,
height=800,
    min_font_size=1,
    max_font_size=500,
    background_color="black"
).generate(text)

image = wordcloud.to_image()
image.show()

image.save('test_list2_wc.png')

img=mpimg.imread('test_list2_wc.png')
plt.figure(figsize = (10,10))
imgplot = plt.imshow(img)
plt.show()

# %%
#Get Most Frequent Words for HW products in comments
from collections import Counter
test_comm4 = Counter(" ".join(test["disadvantages"]).split()).most_common(30)

n = 0 # N. . .
test_list3 = [x[n] for x in test_comm4]

with open("test_list3.txt", "w") as output:
    output.write(str(test_list3))

text = open('test_list3.txt', encoding='utf-8').read()
wordcloud = PersianWordCloud(only_persian=True,
max_words=100,
stopwords=stopwords,
margin=0,
width=800,
height=800,
    min_font_size=1,
    max_font_size=500,
    background_color="black"
).generate(text)

image = wordcloud.to_image()
image.show()

image.save('test_list3_wc.png')

img=mpimg.imread('test_list3_wc.png')
plt.figure(figsize = (10,10))
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# #title_en :

# %% [markdown]
# # 1- IT

# %%
df.title_en.unique()
# Out:
# array(['AC', 'HW', 'MO', 'IT', 'PC', 'PA', 'TC', 'TS', 'MA', 'HA', 'AV',
#        'FA', 'HC', 'BC', 'DF', 'GC', 'FF'], dtype=object)

# %%
df_positive_AC = df_nz[(df_nz['title_en'] == 'IT') & (df_nz['catg_likes'] == '+150') & (df_nz['catg_dislikes'] == '-75')]
# Handsfree Bluetooth
df_positive_AC.head(40)
print('dislikes: ', sum(df_positive_AC.dislikes))
print('likes: ', sum(df_positive_AC.dislikes))
# Out:
# dislikes:  56
# likes:  56

# %%
#Get Most Frequent Words for HW products in comments
from collections import Counter
hw_comm1 = Counter(" ".join(df_positive_AC["disadvantages"]).split()).most_common(30)

n = 0 # N. . .
pos_hw = [x[n] for x in hw_comm1]

with open("pos_hw.txt", "w") as output:
    output.write(str(pos_hw))

text = open('pos_hw.txt', encoding='utf-8').read()
wordcloud = PersianWordCloud(only_persian=True,
max_words=100,
stopwords=stopwords,
margin=0,
width=800,
height=800,
    min_font_size=1,
    max_font_size=500,
    background_color="black"
).generate(text)

image = wordcloud.to_image()
image.show()

image.save('IT_disadvantages.png')

img=mpimg.imread('IT_disadvantages.png')
plt.figure(figsize = (10,10))
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# #2- AC

# %%
df_positive_AC = df_nz[(df_nz['title_en'] == 'AC') & (df_nz['catg_likes'] == '+150') & (df_nz['catg_dislikes'] == '-75')]
# Handsfree Bluetooth
df_positive_AC.head(40)
print('dislikes: ', sum(df_positive_AC.dislikes))
print('likes: ', sum(df_positive_AC.dislikes))
# Out:
# dislikes:  12
# likes:  12

# %%
#Get Most Frequent Words for HW products in comments
from collections import Counter
hw_comm1 = Counter(" ".join(df_positive_AC["disadvantages"]).split()).most_common(30)

n = 0 # N. . .
pos_hw = [x[n] for x in hw_comm1]

with open("pos_hw.txt", "w") as output:
    output.write(str(pos_hw))

text = open('pos_hw.txt', encoding='utf-8').read()
wordcloud = PersianWordCloud(only_persian=True,
max_words=100,
stopwords=stopwords,
margin=0,
width=800,
height=800,
    min_font_size=1,
    max_font_size=500,
    background_color="black"
).generate(text)

image = wordcloud.to_image()
image.show()

image.save('AC_disadvantages.png')

img=mpimg.imread('AC_disadvantages.png')
plt.figure(figsize = (10,10))
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# #3- HW

# %%
df_positive_AC = df_nz[(df_nz['title_en'] == 'HW') & (df_nz['catg_likes'] == '+150') & (df_nz['catg_dislikes'] == '-75')]
# Handsfree Bluetooth
df_positive_AC.head(40)

print('dislikes: ', sum(df_positive_AC.dislikes))
print('likes: ', sum(df_positive_AC.dislikes))
###################################################


#Get Most Frequent Words for HW products in comments
from collections import Counter
hw_comm1 = Counter(" ".join(df_positive_AC["disadvantages"]).split()).most_common(30)

n = 0 # N. . .
pos_hw = [x[n] for x in hw_comm1]

with open("pos_hw.txt", "w") as output:
    output.write(str(pos_hw))

text = open('pos_hw.txt', encoding='utf-8').read()
wordcloud = PersianWordCloud(only_persian=True,
max_words=100,
stopwords=stopwords,
margin=0,
width=800,
height=800,
    min_font_size=1,
    max_font_size=500,
    background_color="black"
).generate(text)

image = wordcloud.to_image()
image.show()

image.save('HW_disadvantages.png')

img=mpimg.imread('HW_disadvantages.png')
plt.figure(figsize = (10,10))
imgplot = plt.imshow(img)
plt.show()
# Out:
# dislikes:  0
# likes:  0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-109-9e3c831643ed> in <module>()
#      28     max_font_size=500,
#      29     background_color="black"
# ---> 30 ).generate(text)
#      31
#      32 image = wordcloud.to_image()
#
# /usr/local/lib/python3.6/dist-packages/persian_wordcloud/wordcloud.py in generate(self, text)
#     143         # reshape persian words
#     144         text = get_display(arabic_reshaper.reshape(text))
# --> 145         return self.generate_from_text(text)
#     146
#     147     @staticmethod
#
# /usr/local/lib/python3.6/dist-packages/wordcloud/wordcloud.py in generate_from_text(self, text)
#     585         """
#     586         words = self.process_text(text)
# --> 587         self.generate_from_frequencies(words)
#     588         return self
#     589
#
# /usr/local/lib/python3.6/dist-packages/wordcloud/wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     381         if len(frequencies) <= 0:
#     382             raise ValueError("We need at least 1 word to plot a word cloud, "
# --> 383                              "got %d." % len(frequencies))
#     384         frequencies = frequencies[:self.max_words]
#     385
#
# ValueError: We need at least 1 word to plot a word cloud, got 0.

# %% [markdown]
# #4- MO

# %%
df_positive_AC = df_nz[(df_nz['title_en'] == 'MO') & (df_nz['catg_likes'] == '+150') & (df_nz['catg_dislikes'] == '-75')]
# Handsfree Bluetooth
df_positive_AC.head(40)
print('dislikes: ', sum(df_positive_AC.dislikes))
print('likes: ', sum(df_positive_AC.dislikes))
###################################################

#Get Most Frequent Words for HW products in comments
from collections import Counter
hw_comm1 = Counter(" ".join(df_positive_AC["disadvantages"]).split()).most_common(30)

n = 0 # N. . .
pos_hw = [x[n] for x in hw_comm1]

with open("pos_hw.txt", "w") as output:
    output.write(str(pos_hw))

text = open('pos_hw.txt', encoding='utf-8').read()
wordcloud = PersianWordCloud(only_persian=True,
max_words=100,
stopwords=stopwords,
margin=0,
width=800,
height=800,
    min_font_size=1,
    max_font_size=500,
    background_color="black"
).generate(text)

image = wordcloud.to_image()
image.show()

image.save('MO_disadvantages.png')

img=mpimg.imread('MO_disadvantages.png')
plt.figure(figsize = (10,10))
imgplot = plt.imshow(img)
plt.show()
# Out:
# dislikes:  102
# likes:  102

# %% [markdown]
# #5-  PC

# %%
df_positive_AC = df_nz[(df_nz['title_en'] == 'PC') & (df_nz['catg_likes'] == '+150') & (df_nz['catg_dislikes'] == '-75')]
# Handsfree Bluetooth
df_positive_AC.head(40)
print('dislikes: ', sum(df_positive_AC.dislikes))
print('likes: ', sum(df_positive_AC.dislikes))
###################################################

#Get Most Frequent Words for HW products in comments
from collections import Counter
hw_comm1 = Counter(" ".join(df_pos_HW["disadvantages"]).split()).most_common(30)

n = 0 # N. . .
pos_hw = [x[n] for x in hw_comm1]

with open("pos_hw.txt", "w") as output:
    output.write(str(pos_hw))

text = open('pos_hw.txt', encoding='utf-8').read()
wordcloud = PersianWordCloud(only_persian=True,
max_words=100,
stopwords=stopwords,
margin=0,
width=800,
height=800,
    min_font_size=1,
    max_font_size=500,
    background_color="black"
).generate(text)

image = wordcloud.to_image()
image.show()

image.save('PC_disadvantages.png')

img=mpimg.imread('PC_disadvantages.png')
plt.figure(figsize = (10,10))
imgplot = plt.imshow(img)
plt.show()
# Out:
# dislikes:  39
# likes:  39

# %% [markdown]
# #6-  PA

# %%
df_positive_AC = df_nz[(df_nz['title_en'] == 'PA') & (df_nz['catg_likes'] == '+150') & (df_nz['catg_dislikes'] == '-75')]
# Handsfree Bluetooth
df_positive_AC.head(40)
print('dislikes: ', sum(df_positive_AC.dislikes))
print('likes: ', sum(df_positive_AC.dislikes))
###################################################

#Get Most Frequent Words for HW products in comments
from collections import Counter
hw_comm1 = Counter(" ".join(df_pos_HW["disadvantages"]).split()).most_common(30)

n = 0 # N. . .
pos_hw = [x[n] for x in hw_comm1]

with open("pos_hw.txt", "w") as output:
    output.write(str(pos_hw))

text = open('pos_hw.txt', encoding='utf-8').read()
wordcloud = PersianWordCloud(only_persian=True,
max_words=100,
stopwords=stopwords,
margin=0,
width=800,
height=800,
    min_font_size=1,
    max_font_size=500,
    background_color="black"
).generate(text)

image = wordcloud.to_image()
image.show()

image.save('PA_disadvantages.png')

img=mpimg.imread('PA_disadvantages.png')
plt.figure(figsize = (10,10))
imgplot = plt.imshow(img)
plt.show()
# Out:
# dislikes:  10
# likes:  10

# %% [markdown]
# #7-  TS

# %%
df_positive_AC = df_nz[(df_nz['title_en'] == 'TS') & (df_nz['catg_likes'] == '+150') & (df_nz['catg_dislikes'] == '-75')]
# Handsfree Bluetooth
df_positive_AC.head(40)
print('dislikes: ', sum(df_positive_AC.dislikes))
print('likes: ', sum(df_positive_AC.dislikes))
###################################################

#Get Most Frequent Words for HW products in comments
from collections import Counter
hw_comm1 = Counter(" ".join(df_positive_AC["disadvantages"]).split()).most_common(30)

n = 0 # N. . .
pos_hw = [x[n] for x in hw_comm1]

with open("pos_hw.txt", "w") as output:
    output.write(str(pos_hw))

text = open('pos_hw.txt', encoding='utf-8').read()
wordcloud = PersianWordCloud(only_persian=True,
max_words=100,
stopwords=stopwords,
margin=0,
width=800,
height=800,
    min_font_size=1,
    max_font_size=500,
    background_color="black"
).generate(text)

image = wordcloud.to_image()
image.show()

image.save('TS_disadvantages.png')

img=mpimg.imread('TS_disadvantages.png')
plt.figure(figsize = (10,10))
imgplot = plt.imshow(img)
plt.show()
# Out:
# dislikes:  0
# likes:  0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-113-5ce51353ba5e> in <module>()
#      26     max_font_size=500,
#      27     background_color="black"
# ---> 28 ).generate(text)
#      29
#      30 image = wordcloud.to_image()
#
# /usr/local/lib/python3.6/dist-packages/persian_wordcloud/wordcloud.py in generate(self, text)
#     143         # reshape persian words
#     144         text = get_display(arabic_reshaper.reshape(text))
# --> 145         return self.generate_from_text(text)
#     146
#     147     @staticmethod
#
# /usr/local/lib/python3.6/dist-packages/wordcloud/wordcloud.py in generate_from_text(self, text)
#     585         """
#     586         words = self.process_text(text)
# --> 587         self.generate_from_frequencies(words)
#     588         return self
#     589
#
# /usr/local/lib/python3.6/dist-packages/wordcloud/wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     381         if len(frequencies) <= 0:
#     382             raise ValueError("We need at least 1 word to plot a word cloud, "
# --> 383                              "got %d." % len(frequencies))
#     384         frequencies = frequencies[:self.max_words]
#     385
#
# ValueError: We need at least 1 word to plot a word cloud, got 0.

# %% [markdown]
# #8- TS

# %%
print(df.title_en.unique())
# Out:
# ['AC' 'HW' 'MO' 'IT' 'PC' 'PA' 'TC' 'TS' 'MA' 'HA' 'AV' 'FA' 'HC' 'BC'
#  'DF' 'GC' 'FF']

# %%
df_positive_AC = df_nz[(df_nz['title_en'] == 'TS') & (df_nz['catg_likes'] == '+150') & (df_nz['catg_dislikes'] == '-75')]
# Handsfree Bluetooth
df_positive_AC.head(40)
print('dislikes: ', sum(df_positive_AC.dislikes))
print('likes: ', sum(df_positive_AC.dislikes))
###################################################

#Get Most Frequent Words for HW products in comments
from collections import Counter
hw_comm1 = Counter(" ".join(df_positive_AC["disadvantages"]).split()).most_common(30)

n = 0 # N. . .
pos_hw = [x[n] for x in hw_comm1]

with open("pos_hw.txt", "w") as output:
    output.write(str(pos_hw))

text = open('pos_hw.txt', encoding='utf-8').read()
wordcloud = PersianWordCloud(only_persian=True,
max_words=100,
stopwords=stopwords,
margin=0,
width=800,
height=800,
    min_font_size=1,
    max_font_size=500,
    background_color="black"
).generate(text)

image = wordcloud.to_image()
image.show()

image.save('TS_comment.png')

img=mpimg.imread('TS_comment.png')
plt.figure(figsize = (10,10))
imgplot = plt.imshow(img)
plt.show()
# Out:
# dislikes:  0
# likes:  0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-115-c63e58ecff0b> in <module>()
#      26     max_font_size=500,
#      27     background_color="black"
# ---> 28 ).generate(text)
#      29
#      30 image = wordcloud.to_image()
#
# /usr/local/lib/python3.6/dist-packages/persian_wordcloud/wordcloud.py in generate(self, text)
#     143         # reshape persian words
#     144         text = get_display(arabic_reshaper.reshape(text))
# --> 145         return self.generate_from_text(text)
#     146
#     147     @staticmethod
#
# /usr/local/lib/python3.6/dist-packages/wordcloud/wordcloud.py in generate_from_text(self, text)
#     585         """
#     586         words = self.process_text(text)
# --> 587         self.generate_from_frequencies(words)
#     588         return self
#     589
#
# /usr/local/lib/python3.6/dist-packages/wordcloud/wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     381         if len(frequencies) <= 0:
#     382             raise ValueError("We need at least 1 word to plot a word cloud, "
# --> 383                              "got %d." % len(frequencies))
#     384         frequencies = frequencies[:self.max_words]
#     385
#
# ValueError: We need at least 1 word to plot a word cloud, got 0.

# %% [markdown]
# #9- MA

# %%
df_positive_AC = df_nz[(df_nz['title_en'] == 'MA') & (df_nz['catg_likes'] == '+150') & (df_nz['catg_dislikes'] == '-75')]
# Handsfree Bluetooth
df_positive_AC.head(40)
print('dislikes: ', sum(df_positive_AC.dislikes))
print('likes: ', sum(df_positive_AC.dislikes))
###################################################

#Get Most Frequent Words for HW products in comments
from collections import Counter
hw_comm1 = Counter(" ".join(df_positive_AC["comment"]).split()).most_common(30)

n = 0 # N. . .
pos_hw = [x[n] for x in hw_comm1]

with open("pos_hw.txt", "w") as output:
    output.write(str(pos_hw))

text = open('pos_hw.txt', encoding='utf-8').read()
wordcloud = PersianWordCloud(only_persian=True,
max_words=100,
stopwords=stopwords,
margin=0,
width=800,
height=800,
    min_font_size=1,
    max_font_size=500,
    background_color="black"
).generate(text)

image = wordcloud.to_image()
image.show()

image.save('MA_comment.png')

img=mpimg.imread('MA_comment.png')
plt.figure(figsize = (10,10))
imgplot = plt.imshow(img)
plt.show()
# Out:
# dislikes:  19
# likes:  19

# %% [markdown]
# # 10- HA

# %%
df_positive_AC = df_nz[(df_nz['title_en'] == 'HA') & (df_nz['catg_likes'] == '+150') & (df_nz['catg_dislikes'] == '-75')]
# Handsfree Bluetooth
df_positive_AC.head(40)
print('dislikes: ', sum(df_positive_AC.dislikes))
print('likes: ', sum(df_positive_AC.dislikes))
###################################################

#Get Most Frequent Words for HW products in comments
from collections import Counter
hw_comm1 = Counter(" ".join(df_positive_AC["comment"]).split()).most_common(30)

n = 0 # N. . .
pos_hw = [x[n] for x in hw_comm1]

with open("pos_hw.txt", "w") as output:
    output.write(str(pos_hw))

text = open('pos_hw.txt', encoding='utf-8').read()
wordcloud = PersianWordCloud(only_persian=True,
max_words=100,
stopwords=stopwords,
margin=0,
width=800,
height=800,
    min_font_size=1,
    max_font_size=500,
    background_color="black"
).generate(text)

image = wordcloud.to_image()
image.show()

image.save('HA_comment.png')

img=mpimg.imread('HA_comment.png')
plt.figure(figsize = (10,10))
imgplot = plt.imshow(img)
plt.show()
# Out:
# dislikes:  0
# likes:  0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-117-361ab91cc08d> in <module>()
#      28     max_font_size=500,
#      29     background_color="black"
# ---> 30 ).generate(text)
#      31
#      32 image = wordcloud.to_image()
#
# /usr/local/lib/python3.6/dist-packages/persian_wordcloud/wordcloud.py in generate(self, text)
#     143         # reshape persian words
#     144         text = get_display(arabic_reshaper.reshape(text))
# --> 145         return self.generate_from_text(text)
#     146
#     147     @staticmethod
#
# /usr/local/lib/python3.6/dist-packages/wordcloud/wordcloud.py in generate_from_text(self, text)
#     585         """
#     586         words = self.process_text(text)
# --> 587         self.generate_from_frequencies(words)
#     588         return self
#     589
#
# /usr/local/lib/python3.6/dist-packages/wordcloud/wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     381         if len(frequencies) <= 0:
#     382             raise ValueError("We need at least 1 word to plot a word cloud, "
# --> 383                              "got %d." % len(frequencies))
#     384         frequencies = frequencies[:self.max_words]
#     385
#
# ValueError: We need at least 1 word to plot a word cloud, got 0.

# %% [markdown]
# # 11- AV

# %%
df_positive_AC = df_nz[(df_nz['title_en'] == 'AV') & (df_nz['catg_likes'] == '+150') & (df_nz['catg_dislikes'] == '-75')]
# Handsfree Bluetooth
df_positive_AC.head(40)
print('dislikes: ', sum(df_positive_AC.dislikes))
print('likes: ', sum(df_positive_AC.dislikes))
###################################################

#Get Most Frequent Words for HW products in comments
from collections import Counter
hw_comm1 = Counter(" ".join(df_positive_AC["comment"]).split()).most_common(30)

n = 0 # N. . .
pos_hw = [x[n] for x in hw_comm1]

with open("pos_hw.txt", "w") as output:
    output.write(str(pos_hw))

text = open('pos_hw.txt', encoding='utf-8').read()
wordcloud = PersianWordCloud(only_persian=True,
max_words=100,
stopwords=stopwords,
margin=0,
width=800,
height=800,
    min_font_size=1,
    max_font_size=500,
    background_color="black"
).generate(text)

image = wordcloud.to_image()
image.show()

image.save('AV_comment.png')

img=mpimg.imread('AV_comment.png')
plt.figure(figsize = (10,10))
imgplot = plt.imshow(img)
plt.show()
# Out:
# dislikes:  46
# likes:  46

# %% [markdown]
# # 12- FA

# %%
df_positive_AC = df_nz[(df_nz['title_en'] == 'FA') & (df_nz['catg_likes'] == '+150') & (df_nz['catg_dislikes'] == '-75')]
# Handsfree Bluetooth
df_positive_AC.head(40)
print('dislikes: ', sum(df_positive_AC.dislikes))
print('likes: ', sum(df_positive_AC.dislikes))
###################################################

#Get Most Frequent Words for HW products in comments
from collections import Counter
hw_comm1 = Counter(" ".join(df_positive_AC["comment"]).split()).most_common(30)

n = 0 # N. . .
pos_hw = [x[n] for x in hw_comm1]

with open("pos_hw.txt", "w") as output:
    output.write(str(pos_hw))

text = open('pos_hw.txt', encoding='utf-8').read()
wordcloud = PersianWordCloud(only_persian=True,
max_words=100,
stopwords=stopwords,
margin=0,
width=800,
height=800,
    min_font_size=1,
    max_font_size=500,
    background_color="black"
).generate(text)

image = wordcloud.to_image()
image.show()

image.save('FA_comment.png')

img=mpimg.imread('FA_comment.png')
plt.figure(figsize = (10,10))
imgplot = plt.imshow(img)
plt.show()
# Out:
# dislikes:  29
# likes:  29

# %% [markdown]
# #13 - HC

# %%
df_positive_AC = df_nz[(df_nz['title_en'] == 'HC') & (df_nz['catg_likes'] == '+150') & (df_nz['catg_dislikes'] == '-75')]
# Handsfree Bluetooth
df_positive_AC.head(40)
print('dislikes: ', sum(df_positive_AC.dislikes))
print('likes: ', sum(df_positive_AC.dislikes))
###################################################

#Get Most Frequent Words for HW products in comments
from collections import Counter
hw_comm1 = Counter(" ".join(df_positive_AC["comment"]).split()).most_common(30)

n = 0 # N. . .
pos_hw = [x[n] for x in hw_comm1]

with open("pos_hw.txt", "w") as output:
    output.write(str(pos_hw))

text = open('pos_hw.txt', encoding='utf-8').read()
wordcloud = PersianWordCloud(only_persian=True,
max_words=100,
stopwords=stopwords,
margin=0,
width=800,
height=800,
    min_font_size=1,
    max_font_size=500,
    background_color="black"
).generate(text)

image = wordcloud.to_image()
image.show()

image.save('HC_comment.png')

img=mpimg.imread('HC_comment.png')
plt.figure(figsize = (10,10))
imgplot = plt.imshow(img)
plt.show()
# Out:
# dislikes:  0
# likes:  0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-120-2e0d371c5fc6> in <module>()
#      28     max_font_size=500,
#      29     background_color="black"
# ---> 30 ).generate(text)
#      31
#      32 image = wordcloud.to_image()
#
# /usr/local/lib/python3.6/dist-packages/persian_wordcloud/wordcloud.py in generate(self, text)
#     143         # reshape persian words
#     144         text = get_display(arabic_reshaper.reshape(text))
# --> 145         return self.generate_from_text(text)
#     146
#     147     @staticmethod
#
# /usr/local/lib/python3.6/dist-packages/wordcloud/wordcloud.py in generate_from_text(self, text)
#     585         """
#     586         words = self.process_text(text)
# --> 587         self.generate_from_frequencies(words)
#     588         return self
#     589
#
# /usr/local/lib/python3.6/dist-packages/wordcloud/wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     381         if len(frequencies) <= 0:
#     382             raise ValueError("We need at least 1 word to plot a word cloud, "
# --> 383                              "got %d." % len(frequencies))
#     384         frequencies = frequencies[:self.max_words]
#     385
#
# ValueError: We need at least 1 word to plot a word cloud, got 0.

# %% [markdown]
# # 14- BC

# %%
df_positive_AC = df_nz[(df_nz['title_en'] == 'BC') & (df_nz['catg_likes'] == '+150') & (df_nz['catg_dislikes'] == '-75')]
# Handsfree Bluetooth
df_positive_AC.head(40)
print('dislikes: ', sum(df_positive_AC.dislikes))
print('likes: ', sum(df_positive_AC.dislikes))
###################################################

#Get Most Frequent Words for HW products in comments
from collections import Counter
hw_comm1 = Counter(" ".join(df_positive_AC["comment"]).split()).most_common(30)

n = 0 # N. . .
pos_hw = [x[n] for x in hw_comm1]

with open("pos_hw.txt", "w") as output:
    output.write(str(pos_hw))

text = open('pos_hw.txt', encoding='utf-8').read()
wordcloud = PersianWordCloud(only_persian=True,
max_words=100,
stopwords=stopwords,
margin=0,
width=800,
height=800,
    min_font_size=1,
    max_font_size=500,
    background_color="black"
).generate(text)

image = wordcloud.to_image()
image.show()

image.save('BC_comment.png')

img=mpimg.imread('BC_comment.png')
plt.figure(figsize = (10,10))
imgplot = plt.imshow(img)
plt.show()
# Out:
# dislikes:  0
# likes:  0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-121-97fd6cf4b849> in <module>()
#      28     max_font_size=500,
#      29     background_color="black"
# ---> 30 ).generate(text)
#      31
#      32 image = wordcloud.to_image()
#
# /usr/local/lib/python3.6/dist-packages/persian_wordcloud/wordcloud.py in generate(self, text)
#     143         # reshape persian words
#     144         text = get_display(arabic_reshaper.reshape(text))
# --> 145         return self.generate_from_text(text)
#     146
#     147     @staticmethod
#
# /usr/local/lib/python3.6/dist-packages/wordcloud/wordcloud.py in generate_from_text(self, text)
#     585         """
#     586         words = self.process_text(text)
# --> 587         self.generate_from_frequencies(words)
#     588         return self
#     589
#
# /usr/local/lib/python3.6/dist-packages/wordcloud/wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     381         if len(frequencies) <= 0:
#     382             raise ValueError("We need at least 1 word to plot a word cloud, "
# --> 383                              "got %d." % len(frequencies))
#     384         frequencies = frequencies[:self.max_words]
#     385
#
# ValueError: We need at least 1 word to plot a word cloud, got 0.

# %% [markdown]
# #15 - DF

# %%
df_positive_AC = df_nz[(df_nz['title_en'] == 'BC') & (df_nz['catg_likes'] == '+150') & (df_nz['catg_dislikes'] == '-75')]
# Handsfree Bluetooth
df_positive_AC.head(40)
print('dislikes: ', sum(df_positive_AC.dislikes))
print('likes: ', sum(df_positive_AC.dislikes))
###################################################

#Get Most Frequent Words for HW products in comments
from collections import Counter
hw_comm1 = Counter(" ".join(df_positive_AC["comment"]).split()).most_common(30)

n = 0 # N. . .
pos_hw = [x[n] for x in hw_comm1]

with open("pos_hw.txt", "w") as output:
    output.write(str(pos_hw))

text = open('pos_hw.txt', encoding='utf-8').read()
wordcloud = PersianWordCloud(only_persian=True,
max_words=100,
stopwords=stopwords,
margin=0,
width=800,
height=800,
    min_font_size=1,
    max_font_size=500,
    background_color="black"
).generate(text)

image = wordcloud.to_image()
image.show()

image.save('DF_comment.png')

img=mpimg.imread('DF_comment.png')
plt.figure(figsize = (10,10))
imgplot = plt.imshow(img)
plt.show()
# Out:
# dislikes:  0
# likes:  0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-122-b403a82a246a> in <module>()
#      28     max_font_size=500,
#      29     background_color="black"
# ---> 30 ).generate(text)
#      31
#      32 image = wordcloud.to_image()
#
# /usr/local/lib/python3.6/dist-packages/persian_wordcloud/wordcloud.py in generate(self, text)
#     143         # reshape persian words
#     144         text = get_display(arabic_reshaper.reshape(text))
# --> 145         return self.generate_from_text(text)
#     146
#     147     @staticmethod
#
# /usr/local/lib/python3.6/dist-packages/wordcloud/wordcloud.py in generate_from_text(self, text)
#     585         """
#     586         words = self.process_text(text)
# --> 587         self.generate_from_frequencies(words)
#     588         return self
#     589
#
# /usr/local/lib/python3.6/dist-packages/wordcloud/wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     381         if len(frequencies) <= 0:
#     382             raise ValueError("We need at least 1 word to plot a word cloud, "
# --> 383                              "got %d." % len(frequencies))
#     384         frequencies = frequencies[:self.max_words]
#     385
#
# ValueError: We need at least 1 word to plot a word cloud, got 0.

# %% [markdown]
# #16- GC

# %%
df_positive_AC = df_nz[(df_nz['title_en'] == 'BC') & (df_nz['catg_likes'] == '+150') & (df_nz['catg_dislikes'] == '-75')]
# Handsfree Bluetooth
df_positive_AC.head(40)
print('dislikes: ', sum(df_positive_AC.dislikes))
print('likes: ', sum(df_positive_AC.dislikes))
###################################################

#Get Most Frequent Words for HW products in comments
from collections import Counter
hw_comm1 = Counter(" ".join(df_positive_AC["comment"]).split()).most_common(30)

n = 0 # N. . .
pos_hw = [x[n] for x in hw_comm1]

with open("pos_hw.txt", "w") as output:
    output.write(str(pos_hw))

text = open('pos_hw.txt', encoding='utf-8').read()
wordcloud = PersianWordCloud(only_persian=True,
max_words=100,
stopwords=stopwords,
margin=0,
width=800,
height=800,
    min_font_size=1,
    max_font_size=500,
    background_color="black"
).generate(text)

image = wordcloud.to_image()
image.show()

image.save('GC_comment.png')

img=mpimg.imread('GC_comment.png')
plt.figure(figsize = (10,10))
imgplot = plt.imshow(img)
plt.show()
# Out:
# dislikes:  0
# likes:  0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-123-e0472f3fa87b> in <module>()
#      28     max_font_size=500,
#      29     background_color="black"
# ---> 30 ).generate(text)
#      31
#      32 image = wordcloud.to_image()
#
# /usr/local/lib/python3.6/dist-packages/persian_wordcloud/wordcloud.py in generate(self, text)
#     143         # reshape persian words
#     144         text = get_display(arabic_reshaper.reshape(text))
# --> 145         return self.generate_from_text(text)
#     146
#     147     @staticmethod
#
# /usr/local/lib/python3.6/dist-packages/wordcloud/wordcloud.py in generate_from_text(self, text)
#     585         """
#     586         words = self.process_text(text)
# --> 587         self.generate_from_frequencies(words)
#     588         return self
#     589
#
# /usr/local/lib/python3.6/dist-packages/wordcloud/wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     381         if len(frequencies) <= 0:
#     382             raise ValueError("We need at least 1 word to plot a word cloud, "
# --> 383                              "got %d." % len(frequencies))
#     384         frequencies = frequencies[:self.max_words]
#     385
#
# ValueError: We need at least 1 word to plot a word cloud, got 0.

# %% [markdown]
# # 17 - GF

# %%
df_positive_AC = df_nz[(df_nz['title_en'] == 'BC') & (df_nz['catg_likes'] == '+150') & (df_nz['catg_dislikes'] == '-75')]
# Handsfree Bluetooth
df_positive_AC.head(40)
print('dislikes: ', sum(df_positive_AC.dislikes))
print('likes: ', sum(df_positive_AC.dislikes))
###################################################

#Get Most Frequent Words for HW products in comments
from collections import Counter
hw_comm1 = Counter(" ".join(df_positive_AC["comment"]).split()).most_common(30)

n = 0 # N. . .
pos_hw = [x[n] for x in hw_comm1]

with open("pos_hw.txt", "w") as output:
    output.write(str(pos_hw))

text = open('pos_hw.txt', encoding='utf-8').read()
wordcloud = PersianWordCloud(only_persian=True,
max_words=100,
stopwords=stopwords,
margin=0,
width=800,
height=800,
    min_font_size=1,
    max_font_size=500,
    background_color="black"
).generate(text)

image = wordcloud.to_image()
image.show()

image.save('GF_comment.png')

img=mpimg.imread('GF_comment.png')
plt.figure(figsize = (10,10))
imgplot = plt.imshow(img)
plt.show()
# Out:
# dislikes:  0
# likes:  0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-124-83bf2c58ae76> in <module>()
#      28     max_font_size=500,
#      29     background_color="black"
# ---> 30 ).generate(text)
#      31
#      32 image = wordcloud.to_image()
#
# /usr/local/lib/python3.6/dist-packages/persian_wordcloud/wordcloud.py in generate(self, text)
#     143         # reshape persian words
#     144         text = get_display(arabic_reshaper.reshape(text))
# --> 145         return self.generate_from_text(text)
#     146
#     147     @staticmethod
#
# /usr/local/lib/python3.6/dist-packages/wordcloud/wordcloud.py in generate_from_text(self, text)
#     585         """
#     586         words = self.process_text(text)
# --> 587         self.generate_from_frequencies(words)
#     588         return self
#     589
#
# /usr/local/lib/python3.6/dist-packages/wordcloud/wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     381         if len(frequencies) <= 0:
#     382             raise ValueError("We need at least 1 word to plot a word cloud, "
# --> 383                              "got %d." % len(frequencies))
#     384         frequencies = frequencies[:self.max_words]
#     385
#
# ValueError: We need at least 1 word to plot a word cloud, got 0.

# %% [markdown]
# # 18- FF

# %%
df_positive_AC = df_nz[(df_nz['title_en'] == 'BC') & (df_nz['catg_likes'] == '+150') & (df_nz['catg_dislikes'] == '-75')]
# Handsfree Bluetooth
df_positive_AC.head(40)
print('dislikes: ', sum(df_positive_AC.dislikes))
print('likes: ', sum(df_positive_AC.dislikes))
###################################################

#Get Most Frequent Words for HW products in comments
from collections import Counter
hw_comm1 = Counter(" ".join(df_positive_AC["comment"]).split()).most_common(30)

n = 0 # N. . .
pos_hw = [x[n] for x in hw_comm1]

with open("pos_hw.txt", "w") as output:
    output.write(str(pos_hw))

text = open('pos_hw.txt', encoding='utf-8').read()
wordcloud = PersianWordCloud(only_persian=True,
max_words=100,
stopwords=stopwords,
margin=0,
width=800,
height=800,
    min_font_size=1,
    max_font_size=500,
    background_color="black"
).generate(text)

image = wordcloud.to_image()
image.show()

image.save('FF_comment.png')

img=mpimg.imread('FF_comment.png')
plt.figure(figsize = (10,10))
imgplot = plt.imshow(img)
plt.show()
# Out:
# dislikes:  0
# likes:  0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-125-0ae906b40104> in <module>()
#      28     max_font_size=500,
#      29     background_color="black"
# ---> 30 ).generate(text)
#      31
#      32 image = wordcloud.to_image()
#
# /usr/local/lib/python3.6/dist-packages/persian_wordcloud/wordcloud.py in generate(self, text)
#     143         # reshape persian words
#     144         text = get_display(arabic_reshaper.reshape(text))
# --> 145         return self.generate_from_text(text)
#     146
#     147     @staticmethod
#
# /usr/local/lib/python3.6/dist-packages/wordcloud/wordcloud.py in generate_from_text(self, text)
#     585         """
#     586         words = self.process_text(text)
# --> 587         self.generate_from_frequencies(words)
#     588         return self
#     589
#
# /usr/local/lib/python3.6/dist-packages/wordcloud/wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     381         if len(frequencies) <= 0:
#     382             raise ValueError("We need at least 1 word to plot a word cloud, "
# --> 383                              "got %d." % len(frequencies))
#     384         frequencies = frequencies[:self.max_words]
#     385
#
# ValueError: We need at least 1 word to plot a word cloud, got 0.
